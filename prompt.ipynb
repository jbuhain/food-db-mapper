# %% [markdown]
# # Sample Prompt: Get the first 10 rows from the processed results, and asks gpt3.5 to filter out SIMILARFOODS

# %%
from openai import OpenAI
import os
import pandas as pd
import ast

client = OpenAI()
client.api_key = os.getenv('OPENAI_API_KEY')
# MAX_TOKENS = 4096
# PROMPT = "Hello. Can you introduce yourself."

# %%
df_new = pd.read_excel('test_results/results_testAll_frida_to_nevo.xlsx')
sample_df = df_new[['FoodName','SIMILARFOODS']].head(50)
sample_df["FILTEREDSIMILARFOODS"] = '{}'
sample_df
# Out:
#                                              FoodName  \
# 0                                     Strawberry, raw
# 1                           Apple, raw, all varieties
# 2                                         Banana, raw
# 3                                         Potato, raw
# 4   Milk, whole, konventional (not organic), 3.5 %...
# 5                                        Parsley, raw
# 6                                           Pear, raw
# 7                                        Rhubarb, raw
# 8                                 Currant, black, raw
# 9                            Yogurt plain, whole milk
# 10                                        Celery, raw
# 11                    Cauliflower, all varieties, raw
# 12                                      Broccoli, raw
# 13                                    Beans, wax, raw
# 14                                         Lemon, raw
# 15                                          Dill, raw
# 16                                          Kale, raw
# 17                                        Carrot, raw
# 18                                       Garfish, raw
# 19                                Cabbage, white, raw
# 20                                      Rose hip, raw
# 21                                    Elderberry, raw
# 22                        Salmon, Atlantic, wild, raw
# 23                         Sweetcorn, on-the-cob, raw
# 24                                   Milk, buttermilk
# 25  Milk, partly skimmed, konventional (not organi...
# 26                                      Mackerel, raw
# 27                                        Almond, raw
# 28                                    Watermelon, raw
# 29                          Pepper, sweet, green, raw
# 30                            Pepper, sweet, red, raw
# 31                                        Radish, raw
# 32                                  Currant, red, raw
# 33                              Brussels sprouts, raw
# 34                                     Beet, red, raw
# 35                                  Cabbage, red, raw
# 36                                        Plaice, raw
# 37                         Celeriac, celery root, raw
# 38                           Herring, pickled, canned
# 39                                       Herring, raw
# 40                              Cabbage, pointed, raw
# 41                                       Spinach, raw
# 42                                    Gooseberry, raw
# 43                  Tomato, ripe, raw, origin unknown
# 44               Water, tap, drinking, average values
# 45                                         Grape, raw
# 46                                   Peas, green, raw
# 47                                        Squash, raw
# 48                                     Artichoke, raw
# 49                            Beans, mung, dried, raw
#
#                                          SIMILARFOODS FILTEREDSIMILARFOODS
# 0                                    {'Strawberries'}                   {}
# 1   {'Cowberries', 'Bilberries', 'Gooseberries', '...                   {}
# 2   {'Grapes white/black with skin', 'Blackberries...                   {}
# 3   {'Potatoes new raw', 'Potatoes raw', 'Potatoes...                   {}
# 4                               {'Milk semi-skimmed'}                   {}
# 5                                   {'Parsley fresh'}                   {}
# 6   {'Cowberries', 'Bilberries', 'Gooseberries', '...                   {}
# 7        {'Celery raw', 'Fennel raw', 'Kohlrabi raw'}                   {}
# 8                                   {'Blackcurrants'}                   {}
# 9   {'Custard vanilla full fat', 'Yoghurt whole mi...                   {}
# 10  {'Cabbage pak-choi raw', 'Celery raw', 'Okra r...                   {}
# 11                                {'Cauliflower raw'}                   {}
# 12  {'Cabbage pak-choi raw', 'Okra raw', 'Broccoli...                   {}
# 13  {'Beans white or brown dried', 'Beans kidney d...                   {}
# 14  {'Grapes white/black with skin', 'Blackberries...                   {}
# 15  {'Cabbage pak-choi raw', 'Cucumber raw', 'Fenn...                   {}
# 16                                 {'Kale curly raw'}                   {}
# 17  {'Cabbage pak-choi raw', 'Okra raw', 'Carrots ...                   {}
# 18                                        {'Oysters'}                   {}
# 19      {'Cabbage pak-choi raw', 'Cabbage green raw'}                   {}
# 20  {'Cowberries', 'Bilberries', 'Gooseberries', '...                   {}
# 21  {'Cowberries', 'Bilberries', 'Gooseberries', '...                   {}
# 22                                        {'Oysters'}                   {}
# 23  {'', 'Beef rump steak raw', 'Barley pearl', 'C...                   {}
# 24                                  {'Yoghurt drink'}                   {}
# 25                              {'Milk semi-skimmed'}                   {}
# 26                                        {'Oysters'}                   {}
# 27                 {'Pine nuts dried', 'Seed sesame'}                   {}
# 28  {'Cowberries', 'Bilberries', 'Gooseberries', '...                   {}
# 29                                       {'Okra raw'}                   {}
# 30                           {'Sweet pepper red raw'}                   {}
# 31                           {'Radish red/white raw'}                   {}
# 32                                     {'Redcurrant'}                   {}
# 33                           {'Cabbage pak-choi raw'}                   {}
# 34  {'Cabbage pak-choi raw', 'Okra raw', 'Cucumber...                   {}
# 35        {'Cabbage pak-choi raw', 'Cabbage red raw'}                   {}
# 36                                        {'Oysters'}                   {}
# 37                                     {'Fennel raw'}                   {}
# 38                                 {'Herring salted'}                   {}
# 39                       {'Herring fresh', 'Oysters'}                   {}
# 40                           {'Cabbage pak-choi raw'}                   {}
# 41  {'Turnip tops raw', 'Cress garden raw', 'Chard...                   {}
# 42                                   {'Gooseberries'}                   {}
# 43                   {'Cucumber raw', 'Tomatoes raw'}                   {}
# 44  {'Water average', 'Water soft 0-50 mg calcium ...                   {}
# 45  {'Cowberries', 'Bilberries', 'Gooseberries', '...                   {}
# 46  {'Beans kidney dried', 'Beans blackeyepesie dr...                   {}
# 47                                   {'Cucumber raw'}                   {}
# 48  {'Artichoke raw', 'Cabbage pak-choi raw', 'Okr...                   {}
# 49                                  {'Lentils dried'}                   {}

# %%
# We turn df to text which we will give to the gpt model
def df_to_text(df):
    rows = []
    for _, row in df.iterrows():
        food_name = row['FoodName']
        similar_foods = row['SIMILARFOODS']
        rows.append(f"FoodName: {food_name}\nSIMILARFOODS: {similar_foods}\nFILTEREDSIMILARFOODS: []\n")
    return '\n'.join(rows)

df_text = df_to_text(sample_df)
print(df_text)
# Out:
# FoodName: Strawberry, raw
# SIMILARFOODS: {'Strawberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Apple, raw, all varieties
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Redcurrant', 'Apple without skin', 'Raspberries', 'Cranberry', 'Apple with skin', 'Blueberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Banana, raw
# SIMILARFOODS: {'Grapes white/black with skin', 'Blackberries', 'Banana', 'Strawberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Potato, raw
# SIMILARFOODS: {'Potatoes new raw', 'Potatoes raw', 'Potatoes old raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Milk, whole, konventional (not organic), 3.5 % fat
# SIMILARFOODS: {'Milk semi-skimmed'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Parsley, raw
# SIMILARFOODS: {'Parsley fresh'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Pear, raw
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Redcurrant', 'Raspberries', 'Cranberry', 'Pear without skin', 'Blueberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Rhubarb, raw
# SIMILARFOODS: {'Celery raw', 'Fennel raw', 'Kohlrabi raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Currant, black, raw
# SIMILARFOODS: {'Blackcurrants'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Yogurt plain, whole milk
# SIMILARFOODS: {'Custard vanilla full fat', 'Yoghurt whole milk with fruit Mona', 'Custard with whipped cream', 'Yoghurt low fat with fruit', 'Custard several flavours full fat', 'Yoghurt low fat', 'Custard no fat with sweeteners', 'Yogurt half fat', 'Custard vanilla low fat', 'Yogurt whole milk', 'Yoghurt/vanilla custard half fat'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Celery, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Celery raw', 'Okra raw', 'Broccoli raw', 'Cucumber raw', 'Fennel raw', 'Purslane raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Cauliflower, all varieties, raw
# SIMILARFOODS: {'Cauliflower raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Broccoli, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Okra raw', 'Broccoli raw', 'Cucumber raw', 'Cauliflower raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Beans, wax, raw
# SIMILARFOODS: {'Beans white or brown dried', 'Beans kidney dried', 'Beans blackeyepesie dried', 'Bean soy dried'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Lemon, raw
# SIMILARFOODS: {'Grapes white/black with skin', 'Blackberries', 'Lemon', 'Strawberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Dill, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Cucumber raw', 'Fennel raw', 'Okra raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Kale, raw
# SIMILARFOODS: {'Kale curly raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Carrot, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Okra raw', 'Carrots raw', 'Cucumber raw', 'Radish red/white raw', 'Fennel raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Garfish, raw
# SIMILARFOODS: {'Oysters'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Cabbage, white, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Cabbage green raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Rose hip, raw
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Redcurrant', 'Raspberries', 'Cranberry', 'Blueberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Elderberry, raw
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Redcurrant', 'Raspberries', 'Cranberry', 'Blueberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Salmon, Atlantic, wild, raw
# SIMILARFOODS: {'Oysters'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Sweetcorn, on-the-cob, raw
# SIMILARFOODS: {'', 'Beef rump steak raw', 'Barley pearl', 'Cabbage pak-choi raw', 'Chervil fresh', 'Millet', 'Okra raw', 'Wheat germ', 'Beef tenderloin steak raw', 'Rice brown raw', 'Cucumber raw', 'Fennel raw', 'Rice white raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Milk, buttermilk
# SIMILARFOODS: {'Yoghurt drink'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Milk, partly skimmed, konventional (not organic), 1.5 % fat
# SIMILARFOODS: {'Milk semi-skimmed'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Mackerel, raw
# SIMILARFOODS: {'Oysters'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Almond, raw
# SIMILARFOODS: {'Pine nuts dried', 'Seed sesame'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Watermelon, raw
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Melon honeydew', 'Redcurrant', 'Raspberries', 'Cranberry', 'Blueberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Pepper, sweet, green, raw
# SIMILARFOODS: {'Okra raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Pepper, sweet, red, raw
# SIMILARFOODS: {'Sweet pepper red raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Radish, raw
# SIMILARFOODS: {'Radish red/white raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Currant, red, raw
# SIMILARFOODS: {'Redcurrant'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Brussels sprouts, raw
# SIMILARFOODS: {'Cabbage pak-choi raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Beet, red, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Okra raw', 'Cucumber raw', 'Radish red/white raw', 'Fennel raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Cabbage, red, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Cabbage red raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Plaice, raw
# SIMILARFOODS: {'Oysters'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Celeriac, celery root, raw
# SIMILARFOODS: {'Fennel raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Herring, pickled, canned
# SIMILARFOODS: {'Herring salted'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Herring, raw
# SIMILARFOODS: {'Herring fresh', 'Oysters'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Cabbage, pointed, raw
# SIMILARFOODS: {'Cabbage pak-choi raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Spinach, raw
# SIMILARFOODS: {'Turnip tops raw', 'Cress garden raw', 'Chard Swiss leaf raw', 'Taro leaves raw', 'Chervil fresh', 'Cabbage pak-choi raw', 'Lettuce lambs raw', 'Mustard leaf raw', 'Chicory raw', 'Spinach raw', 'Okra raw', 'Kale curly raw', 'Cucumber raw', 'Fennel raw', 'Dandelion leaves raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Gooseberry, raw
# SIMILARFOODS: {'Gooseberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Tomato, ripe, raw, origin unknown
# SIMILARFOODS: {'Cucumber raw', 'Tomatoes raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Water, tap, drinking, average values
# SIMILARFOODS: {'Water average', 'Water soft 0-50 mg calcium per litre', 'Water medium 50-100 mg calcium per litre', 'Water hard >100 mg calcium per litre'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Grape, raw
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Grapes white/black with skin', 'Redcurrant', 'Cranberry', 'Blueberries', 'Raspberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Peas, green, raw
# SIMILARFOODS: {'Beans kidney dried', 'Beans blackeyepesie dried', 'Bean soy dried', 'Pea marrowfat legumes dried', 'Beans white or brown dried'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Squash, raw
# SIMILARFOODS: {'Cucumber raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Artichoke, raw
# SIMILARFOODS: {'Artichoke raw', 'Cabbage pak-choi raw', 'Okra raw', 'Cucumber raw', 'Cauliflower raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Beans, mung, dried, raw
# SIMILARFOODS: {'Lentils dried'}
# FILTEREDSIMILARFOODS: []

# %%
MAX_TOKENS = 4096
PROMPT = "Given the following set, could you fill in FILTEREDSIMILARFOODS by choosing the top food names inside SIMILARFOODS that correspond best to FoodName? Make sure that it matches the exact fruit and not just related fruit. Also, you do not have to choose any from the filtered similar food if you believe that none of the filtered foods matches the food name best. Make the output the same format as my input please."

response = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    messages=[
        {
            "role": "system", 
            "content": PROMPT
        },
        {"role": "user", "content": df_text},
    ],
    max_tokens=MAX_TOKENS
)

result = response.choices[0].message.content
print(result)

# %%
MAX_TOKENS = 4096
PROMPT = "Given the following set, could you fill in FILTEREDSIMILARFOODS by choosing the top food names inside SIMILARFOODS that correspond best to FoodName? Make sure that it matches the exact fruit and not just related fruit. Also, you do not have to choose any from the filtered similar food if you believe that none of the filtered foods matches the food name best. Make the output the same format as my input please."

response = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    messages=[
        {
            "role": "system", 
            "content": PROMPT
        },
        {"role": "user", "content": df_text},
    ],
    max_tokens=MAX_TOKENS
)

result = response.choices[0].message.content
print(result)
# Out:
# FoodName: Strawberry, raw
# SIMILARFOODS: {'Strawberries'}
# FILTEREDSIMILARFOODS: ['Strawberries']
#
# FoodName: Apple, raw, all varieties
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Redcurrant', 'Apple without skin', 'Raspberries', 'Cranberry', 'Apple with skin', 'Blueberries'}
# FILTEREDSIMILARFOODS: ['Apple without skin', 'Apple with skin']
#
# FoodName: Banana, raw
# SIMILARFOODS: {'Grapes white/black with skin', 'Blackberries', 'Banana', 'Strawberries'}
# FILTEREDSIMILARFOODS: ['Banana']
#
# FoodName: Potato, raw
# SIMILARFOODS: {'Potatoes new raw', 'Potatoes raw', 'Potatoes old raw'}
# FILTEREDSIMILARFOODS: ['Potatoes raw']
#
# FoodName: Milk, whole, konventional (not organic), 3.5 % fat
# SIMILARFOODS: {'Milk semi-skimmed'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Parsley, raw
# SIMILARFOODS: {'Parsley fresh'}
# FILTEREDSIMILARFOODS: ['Parsley fresh']
#
# FoodName: Pear, raw
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Redcurrant', 'Raspberries', 'Cranberry', 'Pear without skin', 'Blueberries'}
# FILTEREDSIMILARFOODS: ['Pear without skin']
#
# FoodName: Rhubarb, raw
# SIMILARFOODS: {'Celery raw', 'Fennel raw', 'Kohlrabi raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Currant, black, raw
# SIMILARFOODS: {'Blackcurrants'}
# FILTEREDSIMILARFOODS: ['Blackcurrants']
#
# FoodName: Yogurt plain, whole milk
# SIMILARFOODS: {'Custard vanilla full fat', 'Yoghurt whole milk with fruit Mona', 'Custard with whipped cream', 'Yoghurt low fat with fruit', 'Custard several flavours full fat', 'Yoghurt low fat', 'Custard no fat with sweeteners', 'Yogurt half fat', 'Custard vanilla low fat', 'Yogurt whole milk', 'Yoghurt/vanilla custard half fat'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Celery, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Celery raw', 'Okra raw', 'Broccoli raw', 'Cucumber raw', 'Fennel raw', 'Purslane raw'}
# FILTEREDSIMILARFOODS: ['Celery raw']
#
# FoodName: Cauliflower, all varieties, raw
# SIMILARFOODS: {'Cauliflower raw'}
# FILTEREDSIMILARFOODS: ['Cauliflower raw']
#
# FoodName: Broccoli, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Okra raw', 'Broccoli raw', 'Cucumber raw', 'Cauliflower raw'}
# FILTEREDSIMILARFOODS: ['Broccoli raw']
#
# FoodName: Beans, wax, raw
# SIMILARFOODS: {'Beans white or brown dried', 'Beans kidney dried', 'Beans blackeyepesie dried', 'Bean soy dried'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Lemon, raw
# SIMILARFOODS: {'Grapes white/black with skin', 'Blackberries', 'Lemon', 'Strawberries'}
# FILTEREDSIMILARFOODS: ['Lemon']
#
# FoodName: Dill, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Cucumber raw', 'Fennel raw', 'Okra raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Kale, raw
# SIMILARFOODS: {'Kale curly raw'}
# FILTEREDSIMILARFOODS: ['Kale curly raw']
#
# FoodName: Carrot, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Okra raw', 'Carrots raw', 'Cucumber raw', 'Radish red/white raw', 'Fennel raw'}
# FILTEREDSIMILARFOODS: ['Carrots raw']
#
# FoodName: Garfish, raw
# SIMILARFOODS: {'Oysters'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Cabbage, white, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Cabbage green raw'}
# FILTEREDSIMILARFOODS: ['Cabbage white raw']
#
# FoodName: Rose hip, raw
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Redcurrant', 'Raspberries', 'Cranberry', 'Blueberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Elderberry, raw
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Redcurrant', 'Raspberries', 'Cranberry', 'Blueberries'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Salmon, Atlantic, wild, raw
# SIMILARFOODS: {'Oysters'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Sweetcorn, on-the-cob, raw
# SIMILARFOODS: {'', 'Beef rump steak raw', 'Barley pearl', 'Cabbage pak-choi raw', 'Chervil fresh', 'Millet', 'Okra raw', 'Wheat germ', 'Beef tenderloin steak raw', 'Rice brown raw', 'Cucumber raw', 'Fennel raw', 'Rice white raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Milk, buttermilk
# SIMILARFOODS: {'Yoghurt drink'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Milk, partly skimmed, konventional (not organic), 1.5 % fat
# SIMILARFOODS: {'Milk semi-skimmed'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Mackerel, raw
# SIMILARFOODS: {'Oysters'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Almond, raw
# SIMILARFOODS: {'Pine nuts dried', 'Seed sesame'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Watermelon, raw
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Melon honeydew', 'Redcurrant', 'Raspberries', 'Cranberry', 'Blueberries'}
# FILTEREDSIMILARFOODS: ['Melon honeydew']
#
# FoodName: Pepper, sweet, green, raw
# SIMILARFOODS: {'Okra raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Pepper, sweet, red, raw
# SIMILARFOODS: {'Sweet pepper red raw'}
# FILTEREDSIMILARFOODS: ['Sweet pepper red raw']
#
# FoodName: Radish, raw
# SIMILARFOODS: {'Radish red/white raw'}
# FILTEREDSIMILARFOODS: ['Radish red/white raw']
#
# FoodName: Currant, red, raw
# SIMILARFOODS: {'Redcurrant'}
# FILTEREDSIMILARFOODS: ['Redcurrant']
#
# FoodName: Brussels sprouts, raw
# SIMILARFOODS: {'Cabbage pak-choi raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Beet, red, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Okra raw', 'Cucumber raw', 'Radish red/white raw', 'Fennel raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Cabbage, red, raw
# SIMILARFOODS: {'Cabbage pak-choi raw', 'Cabbage red raw'}
# FILTEREDSIMILARFOODS: ['Cabbage red raw']
#
# FoodName: Plaice, raw
# SIMILARFOODS: {'Oysters'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Celeriac, celery root, raw
# SIMILARFOODS: {'Fennel raw'}
# FILTEREDSIMILARFOODS: ['Fennel raw']
#
# FoodName: Herring, pickled, canned
# SIMILARFOODS: {'Herring salted'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Herring, raw
# SIMILARFOODS: {'Herring fresh', 'Oysters'}
# FILTEREDSIMILARFOODS: ['Herring fresh']
#
# FoodName: Cabbage, pointed, raw
# SIMILARFOODS: {'Cabbage pak-choi raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Spinach, raw
# SIMILARFOODS: {'Turnip tops raw', 'Cress garden raw', 'Chard Swiss leaf raw', 'Taro leaves raw', 'Chervil fresh', 'Cabbage pak-choi raw', 'Lettuce lambs raw', 'Mustard leaf raw', 'Chicory raw', 'Spinach raw', 'Okra raw', 'Kale curly raw', 'Cucumber raw', 'Fennel raw', 'Dandelion leaves raw'}
# FILTEREDSIMILARFOODS: ['Spinach raw']
#
# FoodName: Gooseberry, raw
# SIMILARFOODS: {'Gooseberries'}
# FILTEREDSIMILARFOODS: ['Gooseberries']
#
# FoodName: Tomato, ripe, raw, origin unknown
# SIMILARFOODS: {'Cucumber raw', 'Tomatoes raw'}
# FILTEREDSIMILARFOODS: ['Tomatoes raw']
#
# FoodName: Water, tap, drinking, average values
# SIMILARFOODS: {'Water average', 'Water soft 0-50 mg calcium per litre', 'Water medium 50-100 mg calcium per litre', 'Water hard >100 mg calcium per litre'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Grape, raw
# SIMILARFOODS: {'Cowberries', 'Bilberries', 'Gooseberries', 'Blackcurrants', 'Figs fresh', 'Grapes white/black with skin', 'Redcurrant', 'Cranberry', 'Blueberries', 'Raspberries'}
# FILTEREDSIMILARFOODS: ['Grapes white/black with skin']
#
# FoodName: Peas, green, raw
# SIMILARFOODS: {'Beans kidney dried', 'Beans blackeyepesie dried', 'Bean soy dried', 'Pea marrowfat legumes dried', 'Beans white or brown dried'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Squash, raw
# SIMILARFOODS: {'Cucumber raw'}
# FILTEREDSIMILARFOODS: []
#
# FoodName: Artichoke, raw
# SIMILARFOODS: {'Artichoke raw', 'Cabbage pak-choi raw', 'Okra raw', 'Cucumber raw', 'Cauliflower raw'}
# FILTEREDSIMILARFOODS: ['Artichoke raw']
#
# FoodName: Beans, mung, dried, raw
# SIMILARFOODS: {'Lentils dried'}
# FILTEREDSIMILARFOODS: []

# %%
def parse_input_text(input_text):
    data = {
        'FoodName': [],
        'SIMILARFOODS': [],
        'FILTEREDSIMILARFOODS': []
    }
    lines = input_text.strip().split('\n')
    for i in range(0, len(lines), 4):
        if i + 2 < len(lines):
            food_name_line = lines[i].split(': ', 1)
            similar_foods_line = lines[i+1].split(': ', 1)
            filtered_similar_foods_line = lines[i+2].split(': ', 1)

            if len(food_name_line) > 1 and len(similar_foods_line) > 1 and len(filtered_similar_foods_line) > 1:
                food_name = food_name_line[1]
                similar_foods = eval(similar_foods_line[1])
                filtered_similar_foods = eval(filtered_similar_foods_line[1])
                
                data['FoodName'].append(food_name)
                data['SIMILARFOODS'].append(similar_foods)
                data['FILTEREDSIMILARFOODS'].append(filtered_similar_foods)
    
    return pd.DataFrame(data)

# %%
df_response = parse_input_text(result)
sample_df['FILTEREDSIMILARFOODS'] = df_response['FILTEREDSIMILARFOODS']

sample_df
# Out:
#                                              FoodName  \
# 0                                     Strawberry, raw
# 1                           Apple, raw, all varieties
# 2                                         Banana, raw
# 3                                         Potato, raw
# 4   Milk, whole, konventional (not organic), 3.5 %...
# 5                                        Parsley, raw
# 6                                           Pear, raw
# 7                                        Rhubarb, raw
# 8                                 Currant, black, raw
# 9                            Yogurt plain, whole milk
# 10                                        Celery, raw
# 11                    Cauliflower, all varieties, raw
# 12                                      Broccoli, raw
# 13                                    Beans, wax, raw
# 14                                         Lemon, raw
# 15                                          Dill, raw
# 16                                          Kale, raw
# 17                                        Carrot, raw
# 18                                       Garfish, raw
# 19                                Cabbage, white, raw
# 20                                      Rose hip, raw
# 21                                    Elderberry, raw
# 22                        Salmon, Atlantic, wild, raw
# 23                         Sweetcorn, on-the-cob, raw
# 24                                   Milk, buttermilk
# 25  Milk, partly skimmed, konventional (not organi...
# 26                                      Mackerel, raw
# 27                                        Almond, raw
# 28                                    Watermelon, raw
# 29                          Pepper, sweet, green, raw
# 30                            Pepper, sweet, red, raw
# 31                                        Radish, raw
# 32                                  Currant, red, raw
# 33                              Brussels sprouts, raw
# 34                                     Beet, red, raw
# 35                                  Cabbage, red, raw
# 36                                        Plaice, raw
# 37                         Celeriac, celery root, raw
# 38                           Herring, pickled, canned
# 39                                       Herring, raw
# 40                              Cabbage, pointed, raw
# 41                                       Spinach, raw
# 42                                    Gooseberry, raw
# 43                  Tomato, ripe, raw, origin unknown
# 44               Water, tap, drinking, average values
# 45                                         Grape, raw
# 46                                   Peas, green, raw
# 47                                        Squash, raw
# 48                                     Artichoke, raw
# 49                            Beans, mung, dried, raw
#
#                                          SIMILARFOODS  \
# 0                                    {'Strawberries'}
# 1   {'Cowberries', 'Bilberries', 'Gooseberries', '...
# 2   {'Grapes white/black with skin', 'Blackberries...
# 3   {'Potatoes new raw', 'Potatoes raw', 'Potatoes...
# 4                               {'Milk semi-skimmed'}
# 5                                   {'Parsley fresh'}
# 6   {'Cowberries', 'Bilberries', 'Gooseberries', '...
# 7        {'Celery raw', 'Fennel raw', 'Kohlrabi raw'}
# 8                                   {'Blackcurrants'}
# 9   {'Custard vanilla full fat', 'Yoghurt whole mi...
# 10  {'Cabbage pak-choi raw', 'Celery raw', 'Okra r...
# 11                                {'Cauliflower raw'}
# 12  {'Cabbage pak-choi raw', 'Okra raw', 'Broccoli...
# 13  {'Beans white or brown dried', 'Beans kidney d...
# 14  {'Grapes white/black with skin', 'Blackberries...
# 15  {'Cabbage pak-choi raw', 'Cucumber raw', 'Fenn...
# 16                                 {'Kale curly raw'}
# 17  {'Cabbage pak-choi raw', 'Okra raw', 'Carrots ...
# 18                                        {'Oysters'}
# 19      {'Cabbage pak-choi raw', 'Cabbage green raw'}
# 20  {'Cowberries', 'Bilberries', 'Gooseberries', '...
# 21  {'Cowberries', 'Bilberries', 'Gooseberries', '...
# 22                                        {'Oysters'}
# 23  {'', 'Beef rump steak raw', 'Barley pearl', 'C...
# 24                                  {'Yoghurt drink'}
# 25                              {'Milk semi-skimmed'}
# 26                                        {'Oysters'}
# 27                 {'Pine nuts dried', 'Seed sesame'}
# 28  {'Cowberries', 'Bilberries', 'Gooseberries', '...
# 29                                       {'Okra raw'}
# 30                           {'Sweet pepper red raw'}
# 31                           {'Radish red/white raw'}
# 32                                     {'Redcurrant'}
# 33                           {'Cabbage pak-choi raw'}
# 34  {'Cabbage pak-choi raw', 'Okra raw', 'Cucumber...
# 35        {'Cabbage pak-choi raw', 'Cabbage red raw'}
# 36                                        {'Oysters'}
# 37                                     {'Fennel raw'}
# 38                                 {'Herring salted'}
# 39                       {'Herring fresh', 'Oysters'}
# 40                           {'Cabbage pak-choi raw'}
# 41  {'Turnip tops raw', 'Cress garden raw', 'Chard...
# 42                                   {'Gooseberries'}
# 43                   {'Cucumber raw', 'Tomatoes raw'}
# 44  {'Water average', 'Water soft 0-50 mg calcium ...
# 45  {'Cowberries', 'Bilberries', 'Gooseberries', '...
# 46  {'Beans kidney dried', 'Beans blackeyepesie dr...
# 47                                   {'Cucumber raw'}
# 48  {'Artichoke raw', 'Cabbage pak-choi raw', 'Okr...
# 49                                  {'Lentils dried'}
#
#                      FILTEREDSIMILARFOODS
# 0                          [Strawberries]
# 1   [Apple without skin, Apple with skin]
# 2                                [Banana]
# 3                          [Potatoes raw]
# 4                                      []
# 5                         [Parsley fresh]
# 6                     [Pear without skin]
# 7                                      []
# 8                         [Blackcurrants]
# 9                                      []
# 10                           [Celery raw]
# 11                      [Cauliflower raw]
# 12                         [Broccoli raw]
# 13                                     []
# 14                                [Lemon]
# 15                                     []
# 16                       [Kale curly raw]
# 17                          [Carrots raw]
# 18                                     []
# 19                    [Cabbage white raw]
# 20                                     []
# 21                                     []
# 22                                     []
# 23                                     []
# 24                                     []
# 25                                     []
# 26                                     []
# 27                                     []
# 28                       [Melon honeydew]
# 29                                     []
# 30                 [Sweet pepper red raw]
# 31                 [Radish red/white raw]
# 32                           [Redcurrant]
# 33                                     []
# 34                                     []
# 35                      [Cabbage red raw]
# 36                                     []
# 37                           [Fennel raw]
# 38                                     []
# 39                        [Herring fresh]
# 40                                     []
# 41                          [Spinach raw]
# 42                         [Gooseberries]
# 43                         [Tomatoes raw]
# 44                                     []
# 45         [Grapes white/black with skin]
# 46                                     []
# 47                                     []
# 48                        [Artichoke raw]
# 49                                     []

# %%
# Cut the df split it to df's with 50 rows in total. The last split will be <50 but that's ok. Number them in terms of order. Then batch process it. Wait till all of them get processed. Then concatenate the results.
